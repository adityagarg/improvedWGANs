# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
img=mpimg.imread('out_improved_DCGAN/155.png')
plt.imshow(img)

# %%
img1=mpimg.imread('out_DCGAN/081.png')
plt.imshow(img1)
