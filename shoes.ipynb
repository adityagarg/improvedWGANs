# %%
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
from MLP_WGAN import MLP_WGAN
from DCGAN import DC_WGAN

# %% [markdown]
# ## Load data

# %%
train_set=np.load("data/overKneeshoes_32.npy")
train_set.shape
# Out:
# (49, 32, 32, 3)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Defining Parameters

# %%
mb_size = 32
z_dim = 100
n_fig= 16
n_disc = 5
train_epoch = 3000
penalty = 10
x_dim = train_set.shape[1]
color = train_set.shape[3]

# %% [markdown]
# ### DCGAN architecture
# Training and saving the model

# %%
out_dir = 'out_DCGAN_shoes'
mnist_train_dcgan = DC_WGAN(train_set, mb_size, train_epoch, x_dim, z_dim, n_fig, out_dir, color, penalty, n_disc)
history_dcgan=mnist_train_dcgan.training()
# Out:
# (?, 32, 32, 3)
# Iter: 0; D loss: -68.54; G_loss: 29.38
# Iter: 1; D loss: -2.27e+03; G_loss: 1.151e+03
# Iter: 2; D loss: -4.625e+03; G_loss: 2.319e+03
# Iter: 3; D loss: -7.346e+03; G_loss: 3.68e+03
# Iter: 4; D loss: -1.03e+04; G_loss: 5.159e+03
# Iter: 5; D loss: -1.355e+04; G_loss: 6.777e+03
# Iter: 6; D loss: -1.685e+04; G_loss: 8.441e+03
# Iter: 7; D loss: -2.034e+04; G_loss: 1.022e+04
# Iter: 8; D loss: -2.434e+04; G_loss: 1.231e+04
# Iter: 9; D loss: -2.859e+04; G_loss: 1.448e+04
# Iter: 10; D loss: -3.336e+04; G_loss: 1.695e+04
# Iter: 11; D loss: -3.859e+04; G_loss: 1.962e+04
# Iter: 12; D loss: -4.417e+04; G_loss: 2.247e+04
# Iter: 13; D loss: -4.744e+04; G_loss: 2.503e+04
# Iter: 14; D loss: -5.434e+04; G_loss: 2.769e+04
# Iter: 15; D loss: -6.079e+04; G_loss: 3.101e+04
# Iter: 16; D loss: -6.607e+04; G_loss: 3.367e+04
# Iter: 17; D loss: -7.267e+04; G_loss: 3.711e+04
# Iter: 18; D loss: -7.915e+04; G_loss: 4.044e+04
# Iter: 19; D loss: -8.602e+04; G_loss: 4.396e+04
# Iter: 20; D loss: -9.169e+04; G_loss: 4.687e+04
# Iter: 21; D loss: -9.927e+04; G_loss: 5.074e+04
# Iter: 22; D loss: -1.066e+05; G_loss: 5.454e+04
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f60782c7ca8> returned a result with an error set
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f60782c7ca8> returned a result with an error set
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f60782c7ca8> returned a result with an error set
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f60782c7ca8> returned a result with an error set
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f60782c7ca8> returned a result with an error set
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# ~/miniconda2/envs/dlenv/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     555         try:
# --> 556             _png.write_png(renderer._renderer, filename_or_obj, self.figure.dpi)
#     557         finally:
#
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f60782c7ca8> returned a result with an error set
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-930c83f43206> in <module>()
#       1 out_dir = 'out_DCGAN_shoes'
#       2 mnist_train_dcgan = DC_WGAN(train_set, mb_size, train_epoch, x_dim, z_dim, n_fig, out_dir, color, penalty, n_disc)
# ----> 3 history_dcgan=mnist_train_dcgan.training()
#
# ~/WGANs/DCGAN.py in training(self)
#     191                 fig = self.plot(samples)
#     192                 plt.savefig(self.out_dir + '/{}.png'
# --> 193                             .format(str(i).zfill(3)), bbox_inches='tight')
#     194                 i += 1
#     195                 plt.close(fig)
#
# ~/miniconda2/envs/dlenv/lib/python3.5/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# ~/miniconda2/envs/dlenv/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1571             self.set_frameon(frameon)
#    1572
# -> 1573         self.canvas.print_figure(*args, **kwargs)
#    1574
#    1575         if frameon:
#
# ~/miniconda2/envs/dlenv/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2250                 orientation=orientation,
#    2251                 bbox_inches_restore=_bbox_inches_restore,
# -> 2252                 **kwargs)
#    2253         finally:
#    2254             if bbox_inches and restore_bbox:
#
# ~/miniconda2/envs/dlenv/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     557         finally:
#     558             if close:
# --> 559                 filename_or_obj.close()
#     560             renderer.dpi = original_dpi
#     561
#
# OSError: [Errno 28] No space left on device

# %% [markdown]
# ### Plotting Output
# Plotting last 10 images

# %%
fileNames=[]
for root, dirs, files in os.walk(out_dir):
#     print(files)
    for filename in sorted(files):
         if os.path.splitext(filename)[1].lower() =='.png':
                print(root+'/'+filename)
                fileNames.append(root+'/'+filename)
# Out:
# out_DCGAN/000.png
# out_DCGAN/001.png
# out_DCGAN/002.png
# out_DCGAN/003.png
# out_DCGAN/004.png
# out_DCGAN/005.png
# out_DCGAN/006.png
# out_DCGAN/007.png
# out_DCGAN/008.png
# out_DCGAN/009.png
# out_DCGAN/010.png
# out_DCGAN/011.png
# out_DCGAN/012.png
# out_DCGAN/013.png
# out_DCGAN/014.png
# out_DCGAN/015.png
# out_DCGAN/016.png
# out_DCGAN/017.png
# out_DCGAN/018.png
# out_DCGAN/019.png
# out_DCGAN/020.png
# out_DCGAN/021.png
# out_DCGAN/022.png
# out_DCGAN/023.png
# out_DCGAN/024.png
# out_DCGAN/025.png
# out_DCGAN/026.png
# out_DCGAN/027.png
# out_DCGAN/028.png
# out_DCGAN/029.png

# %%
last_n=10
for i in range(-1, -last_n, -1):
    print(fileNames[i])
    img=mpimg.imread(fileNames[i])
    plt.imshow(img)
    plt.show()
    plt.close()
# Out:
# out_DCGAN/029.png
# out_DCGAN/028.png
# out_DCGAN/027.png
# out_DCGAN/026.png
# out_DCGAN/025.png
# out_DCGAN/024.png
# out_DCGAN/023.png
# out_DCGAN/022.png
# out_DCGAN/021.png

# %% [markdown]
# ### Restoring Saved Models
#
# Restoring models saved at every 100th iteration and generating a sample by passing same noise sample.

# %%
out_dir='out_DCGAN'
generateSamples(out_dir)
# Out:
# out_DCGAN/model/model_1
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_1
# out_DCGAN/model/model_10
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_10
# out_DCGAN/model/model_11
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_11
# out_DCGAN/model/model_12
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_12
# out_DCGAN/model/model_13
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_13
# out_DCGAN/model/model_14
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_14
# out_DCGAN/model/model_15
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_15
# out_DCGAN/model/model_16
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_16
# out_DCGAN/model/model_17
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_17
# out_DCGAN/model/model_18
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_18
# out_DCGAN/model/model_19
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_19
# out_DCGAN/model/model_2
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_2
# out_DCGAN/model/model_20
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_20
# out_DCGAN/model/model_21
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_21
# out_DCGAN/model/model_22
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_22
# out_DCGAN/model/model_23
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_23
# out_DCGAN/model/model_24
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_24
# out_DCGAN/model/model_25
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_25
# out_DCGAN/model/model_26
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_26
# out_DCGAN/model/model_27
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_27
# out_DCGAN/model/model_28
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_28
# out_DCGAN/model/model_29
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_29
# out_DCGAN/model/model_3
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_3
# out_DCGAN/model/model_30
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_30
# out_DCGAN/model/model_4
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_4
# out_DCGAN/model/model_5
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_5
# out_DCGAN/model/model_6
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_6
# out_DCGAN/model/model_7
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_7
# out_DCGAN/model/model_8
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_8
# out_DCGAN/model/model_9
# INFO:tensorflow:Restoring parameters from out_DCGAN/model/model_9

# %% [markdown]
# ## MLP

# %%
out_dir = 'out_MLP'
mnist_train_mlp = MLP_WGAN(train_set, mb_size, train_epoch, x_dim, z_dim, n_fig, out_dir, color, penalty, n_disc)
history_mlp=mnist_train_mlp.training()
# Out:
# (?, 28, 28, 1)
# Iter: 0; D loss: 2.454; G_loss: -0.6127
# Iter: 1; D loss: -0.2749; G_loss: -5.159
# Iter: 2; D loss: -0.6761; G_loss: 0.09726
# Iter: 3; D loss: 0.06868; G_loss: 5.095
# Iter: 4; D loss: 0.5456; G_loss: 3.306
# Iter: 5; D loss: 3.567; G_loss: 1.689
# Iter: 6; D loss: -1.142; G_loss: 0.5517
# Iter: 7; D loss: -0.4835; G_loss: -2.627
# Iter: 8; D loss: -6.606; G_loss: -4.255
# Iter: 9; D loss: -9.724; G_loss: -7.7
# Iter: 10; D loss: -12.18; G_loss: -9.643
# Iter: 11; D loss: -14.99; G_loss: -12.1
# Iter: 12; D loss: -13.09; G_loss: -13.03
# Iter: 13; D loss: -18.69; G_loss: -12.95
# Iter: 14; D loss: -14.38; G_loss: -15.86
# Iter: 15; D loss: -12.92; G_loss: -16.98
# Iter: 16; D loss: -15.5; G_loss: -19.97
# Iter: 17; D loss: -13.75; G_loss: -20.41
# Iter: 18; D loss: -14.09; G_loss: -19.69
# Iter: 19; D loss: -12.19; G_loss: -20.36
# Iter: 20; D loss: -15.21; G_loss: -20.76
# Iter: 21; D loss: -12.87; G_loss: -19.78
# Iter: 22; D loss: -12.62; G_loss: -22.12
# Iter: 23; D loss: -11.8; G_loss: -22.09
# Iter: 24; D loss: -11.84; G_loss: -24.28
# Iter: 25; D loss: -12.17; G_loss: -20.43
# Iter: 26; D loss: -11.98; G_loss: -23.26
# Iter: 27; D loss: -11.21; G_loss: -22.05
# Iter: 28; D loss: -13.77; G_loss: -26.6
# Iter: 29; D loss: -13.49; G_loss: -25.93

# %% [markdown]
# ### Plotting

# %%
fileNames=[]
for root, dirs, files in os.walk(out_dir):
    for filename in sorted(files):
        if os.path.splitext(filename)[1].lower() =='.png':
                print(root+'/'+filename)
                fileNames.append(root+'/'+filename)
# Out:
# out_MLP/000.png
# out_MLP/001.png
# out_MLP/002.png
# out_MLP/003.png
# out_MLP/004.png
# out_MLP/005.png
# out_MLP/006.png
# out_MLP/007.png
# out_MLP/008.png
# out_MLP/009.png
# out_MLP/010.png
# out_MLP/011.png
# out_MLP/012.png
# out_MLP/013.png
# out_MLP/014.png
# out_MLP/015.png
# out_MLP/016.png
# out_MLP/017.png
# out_MLP/018.png
# out_MLP/019.png
# out_MLP/020.png
# out_MLP/021.png
# out_MLP/022.png
# out_MLP/023.png
# out_MLP/024.png
# out_MLP/025.png
# out_MLP/026.png
# out_MLP/027.png
# out_MLP/028.png
# out_MLP/029.png

# %%
last_n=10
for i in range(-1, -last_n, -1):
    print(fileNames[i])
    img=mpimg.imread(fileNames[i])
    plt.imshow(img)
    plt.show()
    plt.close()
# Out:
# out_MLP/029.png
# out_MLP/028.png
# out_MLP/027.png
# out_MLP/026.png
# out_MLP/025.png
# out_MLP/024.png
# out_MLP/023.png
# out_MLP/022.png
# out_MLP/021.png

# %% [markdown]
# ### Restoring Previous models

# %%
out_dir='out_MLP'
generateSamples(out_dir)
# Out:
# out_MLP/model/model_1
# INFO:tensorflow:Restoring parameters from out_MLP/model/model_1
# out_MLP/model/model_11
# INFO:tensorflow:Restoring parameters from out_MLP/model/model_11
# out_MLP/model/model_21
# INFO:tensorflow:Restoring parameters from out_MLP/model/model_21
